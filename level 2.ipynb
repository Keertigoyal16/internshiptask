# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # TASK 1

# %% [markdown]
# # Table Booking and Online Delivery

# %%
# Determine the percentage of restaurants that offer table booking and online delivery.

# %%
df = pd.read_csv(r"E:\Internship\datasettask.csv")

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
table_booking_counts = df['Has Table booking'].value_counts(normalize=True) * 100
print(table_booking_counts)
# Out:
# Has Table booking
# No     87.875615
# Yes    12.124385
# Name: proportion, dtype: float64

# %%
online_delivery_counts = df['Has Online delivery'].value_counts(normalize=True) * 100
print(online_delivery_counts)
# Out:
# Has Online delivery
# No     74.337766
# Yes    25.662234
# Name: proportion, dtype: float64

# %%
# Compare the average ratings of restaurants with table booking and those without.

# %%
df.groupby('Has Table booking')['Aggregate rating'].mean() # thats gives the average rating for Restaurants with table booking and Restaurants without table booking
# Out:
# Has Table booking
# No     2.559359
# Yes    3.441969
# Name: Aggregate rating, dtype: float64

# %%
sns.boxplot(x='Has Table booking', y='Aggregate rating', data=df)
# Out:
# <Axes: xlabel='Has Table booking', ylabel='Aggregate rating'>

# %%
# Analyze the availability of online delivery among restaurants with different price ranges.

# %%
pd.crosstab(df['Price range'], df['Has Online delivery'], normalize='index') * 100 #This will give a percentage breakdown of restaurants offering/not offering online delivery in each price range.
# Out:
# Has Online delivery         No        Yes
# Price range
# 1                    84.225923  15.774077
# 2                    58.689367  41.310633
# 3                    70.809659  29.190341
# 4                    90.955631   9.044369

# %%
sns.countplot(x='Price range', hue='Has Online delivery', data=df)
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %% [markdown]
# # TASK 2

# %% [markdown]
# # Price Range Analysis

# %%
# Determine the most common price range among all the restaurants.

# %%
df['Price range'].value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
df['Price range'].mode()[0]
# Out:
# np.int64(1)

# %%
# Calculate the average rating for each price range.

# %%
df.groupby('Price range')['Aggregate rating'].mean()
# Out:
# Price range
# 1    1.999887
# 2    2.941054
# 3    3.683381
# 4    3.817918
# Name: Aggregate rating, dtype: float64

# %%
sns.barplot(x='Price range', y='Aggregate rating', data=df)
plt.show()

# %%
# Identify the color that represents the highest average rating among different price ranges.

# %%
df.groupby(['Price range', 'Rating color'])['Aggregate rating'].mean()
# Out:
# Price range  Rating color
# 1            Dark Green      4.668750
#              Green           4.157639
#              Orange          3.040464
#              Red             2.293548
#              White           0.000000
#              Yellow          3.661842
# 2            Dark Green      4.627536
#              Green           4.159385
#              Orange          3.048491
#              Red             2.300000
#              White           0.000000
#              Yellow          3.671159
# 3            Dark Green      4.646032
#              Green           4.169231
#              Orange          3.097764
#              Red             2.305000
#              White           0.000000
#              Yellow          3.716265
# 4            Dark Green      4.709459
#              Green           4.188144
#              Orange          3.162376
#              Red             2.283333
#              White           0.000000
#              Yellow          3.716000
# ...

# %%
df.groupby(['Price range', 'Rating color'])['Aggregate rating'].mean().sort_values(ascending=False)
# Out:
# Price range  Rating color
# 4            Dark Green      4.709459
# 1            Dark Green      4.668750
# 3            Dark Green      4.646032
# 2            Dark Green      4.627536
# 4            Green           4.188144
# 3            Green           4.169231
# 2            Green           4.159385
# 1            Green           4.157639
# 3            Yellow          3.716265
# 4            Yellow          3.716000
# 2            Yellow          3.671159
# 1            Yellow          3.661842
# 4            Orange          3.162376
# 3            Orange          3.097764
# 2            Orange          3.048491
# 1            Orange          3.040464
# 3            Red             2.305000
# 2            Red             2.300000
# 1            Red             2.293548
# 4            Red             2.283333
# 1            White           0.000000
# 2            White           0.000000
# 3            White           0.000000
# 4            White           0.000000
# ...

# %%
sns.catplot(x='Price range', y='Aggregate rating', hue='Rating color', data=df, kind='bar')
plt.show()

# %% [markdown]
# # TASK 3

# %% [markdown]
# # Feature Engineering

# %%
# Extract additional features from the existing columns, such as the length of the restaurant name or address.

# %%
df['Name Length'] = df['Restaurant Name'].apply(len)

# %%
df['Address Length'] = df['Address'].apply(len)

# %%
df['Name Word Count'] = df['Restaurant Name'].apply(lambda x: len(str(x).split()))

# %%
df['Is Cafe'] = df['Restaurant Name'].apply(lambda x: 1 if 'Cafe' in str(x) else 0)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
# Create new features like "Has Table Booking" or "Has Online Delivery" by encoding categorical variables.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
output=le.fit_transform(df['Has Table booking'])
df['Has Table booking']=output
output=le.fit_transform(df['Has Online delivery'])
df['Has Online delivery']=output
output=le.fit_transform(df['Is delivering now'])
df['Is delivering now']=output
output=le.fit_transform(df['Switch to order menu'])	
df['Switch to order menu']=output

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   int64
#  13  Has Online delivery   9551 non-null   int64
#  14  Is delivering now     9551 non-null   int64
# ...
